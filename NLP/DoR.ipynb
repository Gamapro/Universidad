# %% [markdown]
# ## David Gamaliel Arcos Bravo
# ### Practica DoR

# %%
import numpy as np
import matplotlib.pyplot as plt
import nltk

from sklearn.feature_selection import SelectKBest, chi2
from sklearn import preprocessing
from sklearn import metrics
from nltk.tokenize import TweetTokenizer
from collections import Counter

# %%
def get_files(PATH_TRAIN, PATH_TRAIN_LABELS):
    train, train_labels = [], []
    with open(PATH_TRAIN, 'r', encoding="utf8") as f:
        train = [ line for line in f]
    with open(PATH_TRAIN_LABELS, 'r', encoding="utf8") as f:
        train_labels = f.readlines()
    return train, train_labels

# %%
PATH_TRAIN = 'DatasetAgresividad/mex_train.txt'
PATH_LABELS = 'DatasetAgresividad/mex_train_labels.txt'
tr_txt, tr_y = get_files(PATH_TRAIN, PATH_LABELS)

tr_txt = np.array(tr_txt)
tr_y = np.array(tr_y)

tr_txt.shape, tr_y.shape
# Out:
# ((5544,), (5544,))

# %%
print(Counter(tr_y))
plt.hist(tr_y, bins=2, edgecolor='black', linewidth=1.2) # , color=['red', 'blue'])
plt.show()
# Out:
# Counter({'0\n': 3562, '1\n': 1981, '0': 1})

# %%
tokenizer = TweetTokenizer()
idx = np.random.randint(0, len(tr_txt))
tr_txt[idx]
tokens = tokenizer.tokenize(tr_txt[idx])
print(tokens)
# Out:
# ['@usuario', 'no', 'le', 'entiendo', 'a', 'esta', 'madre', 'jajajaja', '😂', 'pero', 'ya', 'estoy', 'aquí', 'pp', '❤', '️']

# %%
corpus_words = []
for txt in tr_txt:
    corpus_words += tokenizer.tokenize(txt)
print(len(set(corpus_words)))
# Out:
# 13580

# %%
fdist = nltk.FreqDist(corpus_words)
aux = [(fdist[key], key) for key in fdist]
aux.sort()
aux.reverse()
fdist = aux
fdist[:10]
# Out:
# [(3383, 'que'),
#  (3357, 'de'),
#  (2774, '.'),
#  (2629, 'a'),
#  (2433, 'la'),
#  (2266, 'y'),
#  (1824, 'no'),
#  (1613, 'me'),
#  (1505, '!'),
#  (1303, 'el')]

# %%
idx_dict = dict()
for i, (freq, word) in enumerate(fdist):
    idx_dict[word] = i
print(idx_dict['que'])
# Out:
# 0

# %%
def build_bow(tr_txt, V, idx_dict, binary=False):
    X = np.zeros((len(tr_txt), len(V)))
    for i, txt in enumerate(tr_txt):
        tokens = tokenizer.tokenize(txt)
        for token in tokens:
            if token in idx_dict:
                if binary:
                    X[i, idx_dict[token]] = 1
                else:
                    X[i, idx_dict[token]] += 1
    return X

def build_tfidf(tr_txt, V, idx_dict):
    X = build_bow(tr_txt, V, idx_dict, binary=False)
    # TF
    X = X / X.sum(axis=1, keepdims=True)
    # IDF
    df = np.zeros((len(V),))
    for i, txt in enumerate(tr_txt):
        tokens = tokenizer.tokenize(txt)
        for token in tokens:
            if token in idx_dict:
                df[idx_dict[token]] += 1
    idf = np.log(X.shape[0] / ( df + 1e-9) )
    X = X * idf
    return X

bow = build_bow(tr_txt, fdist, idx_dict)
bow.shape
# Out:
# (5544, 13580)

# %% [markdown]
# ## Bolsa de validacion

# %%
val_txt, val_y = get_files(
    'DatasetAgresividad/mex_val.txt',
    'DatasetAgresividad/mex_val_labels.txt'
)

val_txt = np.array(val_txt)
val_y = np.array(val_y)

print(Counter(val_y))
plt.hist(val_y, bins=len(set(val_y))-1)
plt.show()


val_bow = build_bow(val_txt, fdist, idx_dict)
val_bow.shape
# Out:
# Counter({'0\n': 396, '1\n': 219, '0': 1})
# (616, 13580)

# %% [markdown]
# # Clasificacion

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support, f1_score

import warnings

# %%
bow_non_binary = build_bow(tr_txt, fdist, idx_dict, binary=False)
val_bow_non_binary = build_bow(val_txt, fdist, idx_dict, binary=False)

bow_binary = build_bow(tr_txt, fdist, idx_dict, binary=True)
val_bow_binary = build_bow(val_txt, fdist, idx_dict, binary=True)

tfidf = build_tfidf(tr_txt, fdist, idx_dict)
val_tfidf = build_tfidf(val_txt, fdist, idx_dict)

# %%
tr_y = np.array([int(y) for y in tr_y])
val_y = np.array([int(y) for y in val_y])

tr_y[:5], val_y[:5]
# Out:
# (array([0, 0, 0, 1, 0]), array([1, 1, 1, 0, 1]))

# %%
def classify(bow, tr_y, val_bow, val_y):

    parameters = {'C' : [0.05, 0.25, 1.0, 2.0]}
    svr = svm.LinearSVC(class_weight='balanced')
    grid = GridSearchCV(svr, parameters, cv=5, scoring='f1_macro')
    
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')
        grid.fit(bow, tr_y)
    y_pred = grid.predict(val_bow)

    p, r, f, _ = precision_recall_fscore_support(val_y, y_pred, average="macro")

    return accuracy_score(val_y, y_pred), p, r, f, y_pred

# %%
print("Non binary")

acc, p, r, f, non_binary_y_pred = classify(bow_non_binary, tr_y, val_bow_non_binary, val_y)
print(metrics.classification_report(val_y, non_binary_y_pred))

print("Binary")

acc, p, r, f, binary_y_pred = classify(bow_binary, tr_y, val_bow_binary, val_y)
print(metrics.classification_report(val_y, binary_y_pred))

print("TF-IDF")

acc, p, r, f, tf_idf_y_pred = classify(tfidf, tr_y, val_tfidf, val_y)
print(metrics.classification_report(val_y, tf_idf_y_pred))
# Out:
# Non binary
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       397
#            1       0.74      0.77      0.75       219
#
#     accuracy                           0.82       616
#    macro avg       0.80      0.81      0.81       616
# weighted avg       0.82      0.82      0.82       616
#
# Binary
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85       397
#            1       0.73      0.77      0.75       219
#
#     accuracy                           0.81       616
#    macro avg       0.80      0.80      0.80       616
# weighted avg       0.82      0.81      0.82       616
#
# TF-IDF
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84       397
#            1       0.70      0.74      0.72       219
#
#     accuracy                           0.79       616
#    macro avg       0.77      0.78      0.78       616
# weighted avg       0.80      0.79      0.79       616

# %% [markdown]
# ## Tweets clasificados como no agresivos que si lo eran

# %%
for i, (y, y_pred) in enumerate(zip(val_y, binary_y_pred)):
    if y == 1 and y_pred == 0:
        print("Tweet: ", val_txt[i])
# Out:
# Tweet:  así debería ser siempre para que se mueran a la verga
#
# Tweet:  cada día me siento como un perro ovejero tratando de cuidar sus ovejas vale madre pinches rateros póngase a trabajar.😤
#
# Tweet:  ya a cualquier prieto le dicen licenciado peludito tengan madre
#
# Tweet:  su "pura vida" quedó en "pura verga" que se tragaron pinches ticos piojosos
#
# Tweet:  no vayas por el mundo presumiendo tus muchos amores eso es de muy putas.
#
# Tweet:  la que se veía súper mal era demi lovato porque se mamo con el escote y el peinado le quedo feo
#
# Tweet:  ya traigo mi actitud de lunes al cien pinches putos.  me pelan la verga todos
#
# Tweet:  por qué verga mis compañeros de proyecto tienen que ser los más ineptos de todos
#
# Tweet:  una novia intelectual una putona y otra luchona. para que entre las 3 se complementen.
#
# Tweet:  putos locos yo llevo 6 horas y aún no salgo de la segunda isla no mamen.
#
# Tweet:  no me gusta el fútbol pero por putos &gt;:v #noerapenal
#
# Tweet:  no  jajaja ya tiene mucho eso pero tan joto es el mugroso greñudo que bloquea gente 😂
#
# Tweet:  porque ponen equis frase "de mi amor? están putos retrasados? 🙄🙄🙄?
#
# Tweet:  conmigo no funciona la indiferencia.  a mí me ignoras y te vas a la verga .l.
#
# Tweet:  yo a este lo veo medio joto. hasta como que se parece a fabiruchis. 😂😂😂😂
#
# Tweet:  voy a hacer una sección de la luchona y me voy a reír de la luchona pendeja que tengo en face.
#
# Tweet:  vengo a que me pelen la verga todos o no @usuario
#
# Tweet:  hay pinche viejito reumatico mal cogido  ... no lo mando a la verga nomas por que es mi jefe  🤦🏻‍♂😡😡😤
#
# Tweet:  pinche hocicón... ya acepta la voluntad de tu madre... sí es que tienes que lo dudo tu misma madre te mando a la verga del testamento...
#
# Tweet:  que bandera más bonita y que raro que un enfermo maricón la llame suya.
#
# Tweet:  no quería mentarte la madre tan temprano pinche maricón il "buasap" pinche millenial cacha moscas
#
# Tweet:  una buena cogida desde atras empujandote la verga con fuerza mientra te manoseo las tetas haciendote…
#
# Tweet:  lo bueno de que ya haga frío es que ya no van a tener pretexto para subir sus puterias dando los buenos días en calzones. putas.
#
# Tweet:  los putos a chin.... a su madre! ya me harté de seguir todo el mundo seguiré lo que yo quiera.
#
# Tweet:  hace 544 años copernico nos enseño que la tierra gira alrededor del sol y no de ti #hdp #miercolesdeganarseguidores #yotambien
#
# Tweet:  estoy a unas horas de mandarte a la mierda prepárate. 😉
#
# Tweet:  @usuario no tienen abuela madre vergüenza....
#
# Tweet:  chingas a tu madre sí no cumples la promesa que me hiciste hace tiempo.
#
# Tweet:  que clase de enfermo se hace cuentas para insultar y estar de puto ardido después de que lo bloqueaste. neta muerete o algo victor 😡😒✊
#
# Tweet:  mamá luchona tamalera niño héroe y americanista de corazón. #mastechefmx
#
# Tweet:  me caga que los putos artistas extranjeros vengan a nuestro a país a decirnos que es lo que está mal y debemos cambiad.
#
# Tweet:  no mames con el tipo de alado  parece que se está orgasmeando  y es perturbante ? aparte habla un inglés de la verga.
#
# Tweet:  siempre le apuestas al que pierde ya se llevó verga al buzz 😂
#
# Tweet:  @usuario le dices machorra machorrita cuando ella es una bella señorita gata eso es tratarla mal así que ia sabes en que categoría entras
#
# Tweet:  when te convencen de ver narcos gonorrea malparido ijueputa marica no me salgas con tus guevonadas @usuario 😅
#
# Tweet:  ni madres si se quiere ir que se vaya alv. a rogar a la iglesia. no mereces miserias!!!
#
# Tweet:  mis vecinos son lo suficientemente putos para dejarme notas anónimas de que "no les gusta mi música". hoy hay playlist de maná todo el día.
#
# Tweet:  yo quiero que me barras pero mi verga con tu pichita putimadurita
#
# Tweet:  bato eso es algo que a mí y a tus 12 followers nos vale verga.
#
# Tweet:  para ti solo tengo un "vete a la verga" y es eterno.
#
# Tweet:  chingas a tu madre!!! me subiste 100 el gas! idiota yo soy pobre con twitter pero pobre!!
#
# Tweet:  porque putas gallardo de lateral derecho que verga esta pasando aquí si de por si es una gran caca aaaahh
#
# Tweet:  ya te estás pasando de verga con tus cejas amiga date cuenta (todas las mujeres)
#
# Tweet:  xq me mienten de que el suero no da hambre estoy muriendo de dolor del estómago por hambre putos de mierdas
#
# Tweet:  wey en todos lados está de la verga...pero sí pinche #establodeméxico 😪😪😪
#
# Tweet:  ya chingo a su madre la güera loca de trump como lider munfial ya nadie confia en el ni en los gringos...juar...juar...juar...!!!
#
# Tweet:  esto si es no tener madre no tener respeto por absolutamente nada. una cosa es ejecutar al enemigo pero matar con saña a civiles indigna. <url>
#
# Tweet:  nada peor que un joto con el que no quisiste coger. y todo ardido empieza a ofender y hacer un drama 🙎🏼‍♂️
#
# Tweet:  hombres que se ofrecen para cazar putas?....que se puede esperar ? 🤷🏻‍♀️
#
# Tweet:  gallardo ratón verde se te doblan las patas maricón
#
# Tweet:  maricon emo y sexualmente teraotaku  me voy a hacer cortes de manga

# %%
def get_dor(tr_txt):

    tr_subset = tr_txt
    DoR = np.zeros((tr_subset.shape[1], tr_subset.shape[0]), dtype=np.float64)
    tam_V = DoR.shape[0]

    for doc, i in zip(
        tr_subset,
        range(len(tr_subset))
    ):
        nonzero_positions = np.nonzero(doc)[0]
        tam_v = len(nonzero_positions)
        for pos in nonzero_positions:
            DoR[pos, i] = (1 + np.log10(doc[pos])) * np.log10(tam_V/tam_v)

    return DoR

DoR_train = get_dor(bow_non_binary)
DoR_val = get_dor(val_bow_non_binary)

# %%
BoW_base = build_bow(tr_txt, fdist, idx_dict)
DoR_base = get_dor(BoW_base)
DoR_base = preprocessing.normalize(DoR_base, norm='l2')

# %%
feats = SelectKBest(chi2, k=1000)
feats.fit(BoW_base, tr_y)
# Out:
# SelectKBest(k=1000, score_func=<function chi2 at 0x0000013A64D86CA0>)

# %%
best = feats.get_support(indices=True)
len(best)
# Out:
# 1000

# %%
dict_ind_inverse = dict()

for w in idx_dict:
    dict_ind_inverse[idx_dict[w]] = w

# %%
t_words = [dict_ind_inverse[index] for index in best]
t_words
# Out:
# ['de',
#  'a',
#  'la',
#  'me',
#  '!',
#  'el',
#  '@usuario',
#  'en',
#  'verga',
#  'se',
#  'putas',
#  'los',
#  'putos',
#  'mi',
#  'te',
#  '"',
#  'las',
#  'como',
#  'loca',
#  'su',
#  'tu',
#  'una',
#  'pero',
#  '😂',
#  'del',
#  'yo',
#  'pinche',
#  'cuando',
#  'puta',
#  'todos',
#  ':',
#  'son',
#  'estoy',
#  '¿',
#  'les',
#  'hdp',
#  'porque',
#  'sus',
#  'joto',
#  'esta',
#  'está',
#  '…',
#  'q',
#  'soy',
#  'vale',
#  'puto',
#  'pinches',
#  'mis',
#  'quiero',
#  'luchona',
#  'eres',
#  'vida',
#  'mierda',
#  'siempre',
#  '️',
#  '¡',
#  'ese',
#  'tiene',
#  'hoy',
#  'tengo',
#  'día',
#  'maricon',
#  'hijos',
#  'pendejo',
#  '-',
#  'tienen',
#  ')',
#  'hijo',
#  'esos',
#  '(',
#  '😭',
#  'van',
#  'tus',
#  'alguien',
#  '”',
#  '“',
#  '..',
#  'mamá',
#  'pendeja',
#  'sí',
#  '😍',
#  'madres',
#  'dos',
#  'vas',
#  'sé',
#  'méxico',
#  '❤',
#  'amor',
#  'algo',
#  'están',
#  'también',
#  'días',
#  'puedo',
#  'culo',
#  'mundial',
#  'mañana',
#  'años',
#  '2',
#  'mamar',
#  'pendejos',
#  'chingas',
#  'alv',
#  'menos',
#  'cosas',
#  'chingar',
#  'mucho',
#  'casa',
#  'putita',
#  'digo',
#  'mil',
#  'ojalá',
#  'estaba',
#  'deja',
#  'd',
#  'he',
#  've',
#  'sabes',
#  'ustedes',
#  'valer',
#  'unos',
#  'rt',
#  'estos',
#  'siento',
#  'hija',
#  'chinga',
#  'después',
#  'amo',
#  ';',
#  'veo',
#  'pueden',
#  'noche',
#  'chinguen',
#  ':(',
#  'vamos',
#  'perra',
#  'maricón',
#  'buena',
#  '*',
#  'cara',
#  '😩',
#  'horas',
#  'hombres',
#  'digan',
#  '1',
#  'partido',
#  'semana',
#  'dijo',
#  '🖕',
#  'dormir',
#  'chingue',
#  'valen',
#  'pone',
#  'minutos',
#  'dan',
#  'clase',
#  '7',
#  '10',
#  'vergas',
#  'saben',
#  'persona',
#  'huevos',
#  'andar',
#  'mamadas',
#  'necesito',
#  'dejen',
#  'andan',
#  '😱',
#  '😘',
#  'vaya',
#  'valiendo',
#  'puro',
#  'nuevo',
#  'hora',
#  'final',
#  'cagan',
#  'asco',
#  'ando',
#  '🍆',
#  'valió',
#  'triste',
#  'perro',
#  'miedo',
#  'dije',
#  'chile',
#  '😆',
#  'tarea',
#  'nalgas',
#  'agua',
#  'volviendo',
#  'putito',
#  'oye',
#  'importa',
#  'hondureños',
#  'culero',
#  'periodistas',
#  '😏',
#  '💦',
#  '💔',
#  'video',
#  'vete',
#  'ratas',
#  'quiera',
#  'políticos',
#  'poder',
#  'hecho',
#  'contigo',
#  'casi',
#  'bonita',
#  '😔',
#  '|',
#  'word',
#  'selección',
#  'perros',
#  'maldito',
#  'lameculos',
#  'escuela',
#  'vayan',
#  'trump',
#  'messi',
#  'llegar',
#  'hice',
#  'hago',
#  'gringos',
#  'gol',
#  'bola',
#  'vuelve',
#  'valgo',
#  'siguen',
#  'llega',
#  'haces',
#  'fui',
#  'escuchar',
#  'argentina',
#  'viejo',
#  'teresa',
#  'tenemos',
#  'queda',
#  'primero',
#  'pasar',
#  'mía',
#  'mexicanos',
#  'meter',
#  'medio',
#  'llevo',
#  'canción',
#  'acabo',
#  '🤤',
#  'traigo',
#  'quería',
#  'pri',
#  'mando',
#  'machorra',
#  'clases',
#  'cabron',
#  'berga',
#  '&',
#  '#putita',
#  '😕',
#  'vergüenza',
#  'sienten',
#  'respeto',
#  'música',
#  'habla',
#  'aparte',
#  'además',
#  '🙃',
#  '😋',
#  'vivir',
#  'valga',
#  'usar',
#  'pueblo',
#  'pongo',
#  'fiesta',
#  'culeros',
#  'calcuta',
#  'cabrón',
#  'basura',
#  '6',
#  '#putas',
#  '☹',
#  'siente',
#  'salgo',
#  'niños',
#  'hola',
#  'frío',
#  'extraño',
#  'eran',
#  'coger',
#  'claro',
#  'caliente',
#  'cagas',
#  'acaba',
#  'vergazos',
#  'urge',
#  'rateros',
#  'peda',
#  'otros',
#  'facebook',
#  'corruptos',
#  'canciones',
#  'cagada',
#  '@',
#  '<3',
#  '😐',
#  '💖',
#  't',
#  'sigo',
#  'presidente',
#  'peña',
#  'palabras',
#  'ojala',
#  'muerto',
#  'juro',
#  'darte',
#  'chica',
#  'aqui',
#  'ahorita',
#  '😞',
#  'toca',
#  'tierra',
#  'the',
#  'semanas',
#  'sabemos',
#  'puse',
#  'pito',
#  'pendejadas',
#  'metro',
#  'mente',
#  'mentar',
#  'mediocre',
#  'mandó',
#  'mandarte',
#  'luis',
#  'karma',
#  'justo',
#  'idiota',
#  'honduras',
#  'cumpleaños',
#  'comer',
#  'cobarde',
#  'chingón',
#  'chilenos',
#  'carajo',
#  'baño',
#  '#noerapenal',
#  '😝',
#  '🌚',
#  '✊',
#  'vemos',
#  'valiste',
#  'tristes',
#  'tetas',
#  'televisa',
#  'sueño',
#  'sacar',
#  'robar',
#  'puso',
#  'problemas',
#  'pesar',
#  'perras',
#  'panocha',
#  'osorio',
#  'mandan',
#  'jajajajajajaja',
#  'hueva',
#  'hotel',
#  'holanda',
#  'hijas',
#  'hermosa',
#  'ganar',
#  'estados',
#  'escucha',
#  'cuál',
#  'concha',
#  'acabar',
#  '100',
#  '%',
#  '✊🏼',
#  'vergazo',
#  'tuve',
#  'simios',
#  'puerta',
#  'parió',
#  'nieto',
#  'nervios',
#  'malditos',
#  'like',
#  'jugadores',
#  'doble',
#  'argentinos',
#  'adiós',
#  '#hdp',
#  '💜',
#  '👅',
#  'vuelvo',
#  'vuelven',
#  'unidos',
#  'tareas',
#  'salga',
#  'reportero',
#  'ponte',
#  'pedazo',
#  'morras',
#  'maricones',
#  'linda',
#  'hablas',
#  'gustas',
#  'gato',
#  'demasiado',
#  'celos',
#  'america',
#  'alto',
#  'alma',
#  '😻',
#  '👏🏻',
#  '☺',
#  'éste',
#  'when',
#  'vive',
#  'viste',
#  'venezuela',
#  'vayanse',
#  'vatos',
#  'usan',
#  'tremendo',
#  'tinaco',
#  'tatuajes',
#  'seguridad',
#  'sangre',
#  'reputa',
#  'rata',
#  'quedaron',
#  'puebla',
#  'penal',
#  'patria',
#  'pario',
#  'orgullo',
#  'nacos',
#  'mosquitos',
#  'miserables',
#  'jotos',
#  'hocico',
#  'hambre',
#  'halloween',
#  'fumo',
#  'español',
#  'enamorada',
#  'empiezan',
#  'cuerpo',
#  'corrupción',
#  'conocer',
#  'closet',
#  'chingando',
#  'chichis',
#  'azul',
#  'as',
#  'allá',
#  'afuera',
#  '#verga',
#  '#travesti',
#  '😃',
#  '🖕🏽',
#  '🔁',
#  '↪',
#  '—',
#  'árbitro',
#  'zorras',
#  'youtube',
#  'verte',
#  'uso',
#  'traes',
#  'tia',
#  'spotify',
#  'sexy',
#  'seré',
#  'redes',
#  'ratero',
#  'propio',
#  'primaria',
#  'pelas',
#  'nobel',
#  'naco',
#  'muero',
#  'materias',
#  'mate',
#  'litros',
#  'libre',
#  'fav',
#  'enojada',
#  'ejercicio',
#  'eduardo',
#  'dientes',
#  'deseo',
#  'cínicos',
#  'cuanta',
#  'cruz',
#  'coldplay',
#  'cerveza',
#  'canal',
#  'beso',
#  'adivinen',
#  '60',
#  '50',
#  '😚',
#  '💅🏼',
#  'traidores',
#  'trabajando',
#  'santas',
#  'rosa',
#  'robaron',
#  'relaciones',
#  'realmente',
#  'quizás',
#  'queden',
#  'priistas',
#  'priista',
#  'post',
#  'pm',
#  'pizza',
#  'ojete',
#  'of',
#  'ochoa',
#  'numero',
#  'necesidad',
#  'momentos',
#  'mirada',
#  'mero',
#  'merecen',
#  'mejores',
#  'malas',
#  'lujo',
#  'locura',
#  'llegan',
#  'lame',
#  'juegan',
#  'josé',
#  'jalando',
#  'jajajajajajajaja',
#  'irme',
#  'intoxicados',
#  'intensa',
#  'imbéciles',
#  'humano',
#  'hojas',
#  'gordas',
#  'g',
#  'futuro',
#  'faltar',
#  'exámenes',
#  'estúpido',
#  'escuchan',
#  'escuchado',
#  'escribió',
#  'entiende',
#  'ecuador',
#  'disfrutar',
#  'diferentes',
#  'defendiendo',
#  'daba',
#  'cuéntale',
#  'cumplir',
#  'culito',
#  'conversaciones',
#  'contando',
#  'cita',
#  'china',
#  'chairos',
#  'carlos',
#  'capítulo',
#  'bailando',
#  'baila',
#  'atrás',
#  'asquerosa',
#  'aquel',
#  'ano',
#  ':/',
#  '#rusia2018',
#  '#pedarumboarusia',
#  '#méxico',
#  '#exo',
#  'éstos',
#  'yankees',
#  'vengas',
#  'traidor',
#  'ticos',
#  'respetan',
#  'reputisima',
#  'ra',
#  'politicos',
#  'marrano',
#  'largate',
#  'ladrón',
#  'ladrones',
#  'indios',
#  'hipócrita',
#  'estúpida',
#  'enano',
#  'cárcel',
#  'cool',
#  'comunidad',
#  'cobran',
#  'chingues',
#  'chinge',
#  'ches',
#  'cerebro',
#  'boquita',
#  'arbitro',
#  'antoja',
#  'anciano',
#  'alentar',
#  '#holanda',
#  '🤮',
#  '🤑',
#  '🖕🏼',
#  '👋🏼',
#  '🐀',
#  'vestirse',
#  'vendido',
#  'técnico',
#  'traigan',
#  'toquen',
#  'soporto',
#  'sinvergüenzas',
#  'saquen',
#  'river',
#  'renuncia',
#  'quisieras',
#  'póngase',
#  'presidencia',
#  'portada',
#  'ponerte',
#  'pierdan',
#  'piedra',
#  'pezones',
#  'perrito',
#  'narizones',
#  'narcopoliticos',
#  'naca',
#  'morder',
#  'mierd',
#  'meterle',
#  'metan',
#  'maña',
#  'mato',
#  'mamás',
#  'maman',
#  'malparido',
#  'lozano',
#  'llorones',
#  'llegando',
#  'lacra',
#  'jijo',
#  'jefes',
#  'infierno',
#  'ignorantes',
#  'humildad',
#  'heterosexuales',
#  'habían',
#  'habría',
#  'hables',
#  'guapa',
#  'gerardo',
#  'futbolistas',
#  'estupido',
#  'embona',
#  'dybala',
#  'desaparecer',
#  'degenerado',
#  'defender',
#  'dedica',
#  'daño',
#  'damnificados',
#  'contento',
#  'cobrar',
#  'cobardes',
#  'chingan',
#  'changos',
#  'campeón',
#  'calvo',
#  'bis',
#  'australia',
#  'aguante',
#  'agarraron',
#  'aeropuerto',
#  '🤘🏼',
#  '🙌🏼',
#  '😵',
#  '🇳🇱',
#  '✊🏽',
#  'échale',
#  'zorro',
#  'yuriko',
#  'youtubers',
#  'wila',
#  'víctima',
#  'vividor',
#  'violador',
#  'vidal',
#  'victor',
#  'vicioso',
#  'verja',
#  'venganza',
#  'varo',
#  'vaqueros',
#  'vaciarme',
#  'usarán',
#  'usaron',
#  'trunca',
#  'triunfo',
#  'trató',
#  'tramposos',
#  'tramposo',
#  'tragan',
#  'tiroteo',
#  'teta',
#  'tenías',
#  'tendré',
#  'temblor',
#  'tecates',
#  'tarugos',
#  'suplentes',
#  'sufriendo',
#  'sueldo',
#  'sudamericanos',
#  'soltado',
#  'saques',
#  'saqueo',
#  'santander',
#  'saludable',
#  'saliste',
#  'saldrá',
#  'sabias',
#  'río',
#  'roba',
#  'ridículos',
#  'reverendo',
#  'respetos',
#  'reputísima',
#  'reportó',
#  'reglas',
#  'reforma',
#  'refieren',
#  'ranchero',
#  'ramos',
#  'quiénes',
#  'qui',
#  'queremos',
#  'quedado',
#  'putote',
#  'pulido',
#  'puchas',
#  'publican',
#  'puberto',
#  'preñada',
#  'presumes',
#  'prensa',
#  'prd',
#  'pose',
#  'portugués',
#  'populista',
#  'plata',
#  'pitos',
#  'pija',
#  'pgj',
#  'peru',
#  'periodismo',
#  'percepción',
#  'pendejete',
#  'pendejazo',
#  'pegelagarto',
#  'pedrito',
#  'pedimos',
#  'payasos',
#  'patas',
#  'partiría',
#  'parido',
#  'parezca',
#  'parale',
#  'panameña',
#  'pagas',
#  'oyos',
#  'organizan',
#  'orate',
#  'opinar',
#  'oooo',
#  'ohhh',
#  'ofrecidas',
#  'oficinas',
#  'ofenden',
#  'obsesionada',
#  'objetivo',
#  'nenas',
#  'nena',
#  'necio',
#  'navas',
#  'musicales',
#  'murat',
#  'mueres',
#  'mueran',
#  'motivacional',
#  'morros',
#  'montoneros',
#  'mon',
#  'miseria',
#  'millonarios',
#  'mierderos',
#  'metertela',
#  'metaleros',
#  'mentes',
#  'memo',
#  'mediocridad',
#  'meca',
#  'mañosos',
#  'masculino',
#  'manejar',
#  'manejan',
#  'malvinas',
#  'maletas',
#  'maldecir',
#  'magia',
#  'llenarte',
#  'llenadera',
#  'llegara',
#  'ligar',
#  'ley',
#  'lata',
#  'larguen',
#  'lamehuevos',
#  'laferte',
#  'jálate',
#  'jugo',
#  'juegas',
#  'jsjaja',
#  'jotito',
#  'joserra',
#  'jerry',
#  'jajajajajjaja',
#  'jajajaa',
#  'insulto',
#  'insta',
#  'infonavit',
#  'inflado',
#  'infeliz',
#  'imbeciles',
#  'imagenes',
#  'ilegales',
#  'ignorancia',
#  'idiotas',
#  'huevonas',
#  'hocicon',
#  'hipócritas',
#  'hipocritas',
#  'hijodeputa',
#  'hielo',
#  'guatemalteco',
#  'grites',
#  'gringo',
#  'gordito',
#  'gobernantes',
#  'gasolina',
#  'garchar',
#  'gano',
#  'ganarle',
#  'ganamos',
#  'gachupines',
#  'funcionario',
#  'firmas',
#  'finales',
#  'fernando',
#  'feministas',
#  'fa',
#  'f',
#  'exquisita',
#  'exacto',
#  'estupida',
#  'estacionamientos',
#  'esq',
#  'especialmente',
#  'escuincle',
#  'epn',
#  'envidia',
#  'entregué',
#  'entradas',
#  'encabronados',
#  'embarrarte',
#  'embarazo',
#  'eliminen',
#  'eliminados',
#  'edomex',
#  'ecuatorianos',
#  'echaron',
#  'déjense',
#  'doler',
#  'divo',
#  'disfrazado',
#  'disciplina',
#  'diputado',
#  'dioses',
#  'dineral',
#  'dilo',
#  'diego',
#  'dibujar',
#  'desviado',
#  'destruir',
#  'demuestra',
#  'delincuentes',
#  'daniela',
#  'césar',
#  'cámaras',
#  'curas',
#  'cuernos',
#  'crossfiteros',
#  'creído',
#  'creían',
#  'costly',
#  'costarica',
#  'corrupta',
#  'corran',
#  'coordinadores',
#  'conflicto',
#  'confiamos',
#  'condones',
#  'condiciones',
#  'comunión',
#  'compran',
#  'compartiendo',
#  'colectivo',
#  'cojerte',
#  'cogen',
#  'cobre',
#  'cleveland',
#  'cholo',
#  'chismes',
#  'chingen',
#  'chingarse',
#  'chillón',
#  'chillones',
#  'chileno',
#  'cerdo',
#  'cerdita',
#  'celebra',
#  'catrachos',
#  'casadas',
#  'carril',
#  'carcel',
#  'cagues',
#  'caeli',
#  'cabras',
#  'buchona',
#  'brasil',
#  'bofo',
#  'bio',
#  'bax',
#  'balazos',
#  'ayyyy',
#  'australiano',
#  'atlas',
#  'asu',
#  'arrastrado',
#  'ardidos',
#  'ardido',
#  'apoyando',
#  'aplauden',
#  'andarle',
#  'andaba',
#  'analizar',
#  'analista',
#  'amistades',
#  'amiguitas',
#  'amig',
#  'amarilla',
#  'altere',
#  'alonso',
#  'alemania',
#  'alegría',
#  'albañil',
#  'agárrense',
#  'agreguen',
#  'agarraba',
#  'afloje',
#  'aficion',
#  'admirar',
#  'acomplejado',
#  'aburren',
#  'abris',
#  'abres',
#  'abran',
#  'abogadin',
#  '=',
#  '70',
#  '#unmomentodeldiapara',
#  '#televisa',
#  '#osorio',
#  '#oaxaca',
#  '#nadapersonal',
#  '#miércolesdementadas',
#  '#losricossepierdende',
#  '#laislareality',
#  '#fuerzamexico',
#  '#cruzazul']

# %%
target_matrix = np.array([
    DoR_base[
        idx_dict[word]
    ]
    for word in t_words
])

target_matrix.shape
# Out:
# (1000, 5544)

# %%
from tsne import tsne

# %%
reduced_matrix = tsne(target_matrix, 2)
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 1000...
# Computing P-values for point 500 of 1000...
# Mean value of sigma: 0.097910
# Iteration 10: error is 17.522743
# Iteration 20: error is 17.235706
# Iteration 30: error is 17.007986
# Iteration 40: error is 17.063415
# Iteration 50: error is 17.033412
# Iteration 60: error is 17.031667
# Iteration 70: error is 17.017917
# Iteration 80: error is 17.011120
# Iteration 90: error is 17.009345
# Iteration 100: error is 16.992566
# Iteration 110: error is 1.977041
# Iteration 120: error is 1.500538
# Iteration 130: error is 1.314272
# Iteration 140: error is 1.208371
# Iteration 150: error is 1.140180
# Iteration 160: error is 1.095121
# Iteration 170: error is 1.062576
# Iteration 180: error is 1.036909
# Iteration 190: error is 1.016550
# Iteration 200: error is 1.000361
# Iteration 210: error is 0.987168
# Iteration 220: error is 0.976159
# Iteration 230: error is 0.966895
# Iteration 240: error is 0.958940
# Iteration 250: error is 0.952023
# Iteration 260: error is 0.946121
# Iteration 270: error is 0.941100
# Iteration 280: error is 0.936695
# Iteration 290: error is 0.932804
# Iteration 300: error is 0.929452
# Iteration 310: error is 0.926524
# Iteration 320: error is 0.923966
# Iteration 330: error is 0.921740
# Iteration 340: error is 0.919754
# Iteration 350: error is 0.917967
# Iteration 360: error is 0.916375
# Iteration 370: error is 0.914960
# Iteration 380: error is 0.913685
# Iteration 390: error is 0.912553
# Iteration 400: error is 0.911547
# Iteration 410: error is 0.910641
# Iteration 420: error is 0.909814
# Iteration 430: error is 0.909072
# Iteration 440: error is 0.908392
# Iteration 450: error is 0.907757
# Iteration 460: error is 0.907170
# Iteration 470: error is 0.906646
# Iteration 480: error is 0.906171
# Iteration 490: error is 0.905730
# Iteration 500: error is 0.905322
# Iteration 510: error is 0.904941
# Iteration 520: error is 0.904584
# Iteration 530: error is 0.904252
# Iteration 540: error is 0.903952
# Iteration 550: error is 0.903671
# Iteration 560: error is 0.903407
# Iteration 570: error is 0.903158
# Iteration 580: error is 0.902926
# Iteration 590: error is 0.902709
# Iteration 600: error is 0.902504
# Iteration 610: error is 0.902314
# Iteration 620: error is 0.902134
# Iteration 630: error is 0.901958
# Iteration 640: error is 0.901785
# Iteration 650: error is 0.901614
# Iteration 660: error is 0.901442
# Iteration 670: error is 0.901269
# Iteration 680: error is 0.901078
# Iteration 690: error is 0.900927
# Iteration 700: error is 0.900799
# Iteration 710: error is 0.900679
# Iteration 720: error is 0.900565
# Iteration 730: error is 0.900460
# Iteration 740: error is 0.900361
# Iteration 750: error is 0.900269
# Iteration 760: error is 0.900176
# Iteration 770: error is 0.900073
# Iteration 780: error is 0.899986
# Iteration 790: error is 0.899908
# Iteration 800: error is 0.899835
# Iteration 810: error is 0.899764
# Iteration 820: error is 0.899695
# Iteration 830: error is 0.899627
# Iteration 840: error is 0.899562
# Iteration 850: error is 0.899499
# Iteration 860: error is 0.899437
# Iteration 870: error is 0.899377
# Iteration 880: error is 0.899317
# Iteration 890: error is 0.899258
# Iteration 900: error is 0.899197
# Iteration 910: error is 0.899135
# Iteration 920: error is 0.899074
# Iteration 930: error is 0.899017
# Iteration 940: error is 0.898965
# Iteration 950: error is 0.898916
# Iteration 960: error is 0.898869
# Iteration 970: error is 0.898827
# Iteration 980: error is 0.898787
# Iteration 990: error is 0.898750
# Iteration 1000: error is 0.898713

# %%
max_x = np.amax(reduced_matrix, axis=0)[0]
max_y = np.amax(reduced_matrix, axis=0)[1]

import matplotlib.pyplot as plt
# %matplotlib inline

from nltk.corpus import stopwords

sw = set(stopwords.words("spanish"))

plt.figure(figsize=(40, 40), dpi=100); 
plt.xlim((-max_x,max_x)); 
plt.ylim((-max_y,max_y))
plt.scatter(reduced_matrix[:, 0], reduced_matrix[:, 1], 20, color="black");

for idx, word in enumerate(t_words[:]):
    x = reduced_matrix[idx, 0]
    y = reduced_matrix[idx, 1]  
    if word in sw:
        plt.annotate(word, (x,y), color="red")
    else: 
        plt.annotate(word, (x,y), color="black")
# Out:
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128405 (\N{REVERSED HAND WITH MIDDLE FINGER EXTENDED}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127814 (\N{AUBERGINE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128166 (\N{SPLASHING SWEAT SYMBOL}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128148 (\N{BROKEN HEART}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 129316 (\N{DROOLING FACE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128579 (\N{UPSIDE-DOWN FACE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128150 (\N{SPARKLING HEART}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127770 (\N{NEW MOON WITH FACE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 9994 (\N{RAISED FIST}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127996 (\N{EMOJI MODIFIER FITZPATRICK TYPE-3}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128156 (\N{PURPLE HEART}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128069 (\N{TONGUE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128079 (\N{CLAPPING HANDS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127995 (\N{EMOJI MODIFIER FITZPATRICK TYPE-1-2}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127997 (\N{EMOJI MODIFIER FITZPATRICK TYPE-4}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128133 (\N{NAIL POLISH}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 129326 (\N{FACE WITH OPEN MOUTH VOMITING}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 129297 (\N{MONEY-MOUTH FACE}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128075 (\N{WAVING HAND SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128000 (\N{RAT}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 129304 (\N{SIGN OF THE HORNS}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 128588 (\N{PERSON RAISING BOTH HANDS IN CELEBRATION}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127475 (\N{REGIONAL INDICATOR SYMBOL LETTER N}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 127473 (\N{REGIONAL INDICATOR SYMBOL LETTER L}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128405 (\N{REVERSED HAND WITH MIDDLE FINGER EXTENDED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127814 (\N{AUBERGINE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128166 (\N{SPLASHING SWEAT SYMBOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128148 (\N{BROKEN HEART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129316 (\N{DROOLING FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128579 (\N{UPSIDE-DOWN FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128150 (\N{SPARKLING HEART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127770 (\N{NEW MOON WITH FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9994 (\N{RAISED FIST}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127996 (\N{EMOJI MODIFIER FITZPATRICK TYPE-3}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128156 (\N{PURPLE HEART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128069 (\N{TONGUE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128079 (\N{CLAPPING HANDS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127995 (\N{EMOJI MODIFIER FITZPATRICK TYPE-1-2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127997 (\N{EMOJI MODIFIER FITZPATRICK TYPE-4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128257 (\N{CLOCKWISE RIGHTWARDS AND LEFTWARDS OPEN CIRCLE ARROWS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128133 (\N{NAIL POLISH}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129326 (\N{FACE WITH OPEN MOUTH VOMITING}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129297 (\N{MONEY-MOUTH FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128075 (\N{WAVING HAND SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128000 (\N{RAT}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 129304 (\N{SIGN OF THE HORNS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128588 (\N{PERSON RAISING BOTH HANDS IN CELEBRATION}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127475 (\N{REGIONAL INDICATOR SYMBOL LETTER N}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\David Arcos\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127473 (\N{REGIONAL INDICATOR SYMBOL LETTER L}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
