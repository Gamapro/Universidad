# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
def f(x):
    return 0.35 + 0.25*x

def random_data():
    # labels = np.random.randint(2, size=2000)
    data = np.random.rand(2, 2000)
    labels = np.array( [ 0 if f(x) < y else 1 for x,y in zip(data[0], data[1]) ] )
    return data, labels

data, labels = random_data()
df = pd.DataFrame(data=[data[0], data[1], labels], index=['x','y','label']).T
data = data.T
df.head()
# Out:
#           x         y  label
# 0  0.293502  0.276772    1.0
# 1  0.787686  0.338118    1.0
# 2  0.940257  0.086534    1.0
# 3  0.318693  0.852098    0.0
# 4  0.765704  0.750145    0.0

# %%
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
class Classifier:

    def __init__(self, data, labels, df):
        self.data = data
        self.labels = labels
        self.df = df
        self.b0 = 0
        self.b = 0
        self.lr = 0.001

    def h(self, X):
        a,b = X.shape
        X = np.concatenate( (np.ones() , X), axis=1 )

    def cost(self,x,y):
        hx = self.h(x)
        return -( y*np.sum( y*np.log(hx) + (1-y)*np.log(1-hx) ))

    def dCost(self, x,y):
        a,b = x.shape()
        x = np.concatenate( (np.ones() , x), axis=1 )

    def fit(self):
        self.show()

    def predict(self):
        pred = np.array( [  ] )
        return pred

    def show(self):
        plt.clf()
        fig, ax = plt.subplots(figsize=(8,8))
        df = pd.DataFrame(data=[x,y,self.predict()],columns=['x','y','label'])
        sb.scatterplot(data=self.df, x='x', y='y', hue='label',ax=ax)
        plt.show()

model = Classifier(data, labels, df)
